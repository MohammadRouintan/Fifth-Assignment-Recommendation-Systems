# %% [markdown]
# # Amazon - Ratings (Beauty Products)
# __Author__ : Mohammad Rouintan , 400222042
#
# __Course__ : Undergraduate Data Science Course

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.decomposition import TruncatedSVD
from surprise import Dataset,SVD , Reader, model_selection
from surprise.model_selection import cross_validate, KFold

# %%
ratings = pd.read_csv('/kaggle/input/amazon-ratings/ratings_Beauty.csv')
ratings.dropna(inplace=True)
ratings.drop_duplicates(inplace=True)
ratings.shape
# Out:
# (2023070, 4)

# %%
ratings.head()
# Out:
#            UserId   ProductId  Rating   Timestamp
# 0  A39HTATAQ9V7YF  0205616461     5.0  1369699200
# 1  A3JM6GV9MNOF9X  0558925278     3.0  1355443200
# 2  A1Z513UWSAAO0F  0558925278     5.0  1404691200
# 3  A1WMRR494NWEWV  0733001998     4.0  1382572800
# 4  A3IAAVS479H7M7  0737104473     1.0  1274227200

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2023070 entries, 0 to 2023069
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   UserId     object
#  1   ProductId  object
#  2   Rating     float64
#  3   Timestamp  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.7+ MB

# %%
ratings.columns
# Out:
# Index(['UserId', 'ProductId', 'Rating', 'Timestamp'], dtype='object')

# %%
ratings.nunique()
# Out:
# UserId       1210271
# ProductId     249274
# Rating             5
# Timestamp       4231
# dtype: int64

# %% [markdown]
# ## Recommendation System
# ### Model-based collaborative filtering system

# %%
ratings_sample = ratings.sample(25_000, random_state=42)

# %%
ratings_matrix = ratings_sample.pivot_table(values='Rating', index='UserId', columns='ProductId', fill_value=0)
ratings_matrix.head()
# Out:
# ProductId              1304511081  3227001381  7535842801  832900094X  \
# UserId
# A0010876CNE3ILIM9HV0            0           0           0           0
# A004205218STRNUW6PPPA           0           0           0           0
# A00473363TJ8YSZ3YAGG9           0           0           0           0
# A00540051HYJDHVJB2FRO           0           0           0           0
# A0109071NOSV8FSC7VNY            0           0           0           0
#
# ProductId              9571044822  9602617918  9746427962  9748776093  \
# UserId
# A0010876CNE3ILIM9HV0            0           0           0           0
# A004205218STRNUW6PPPA           0           0           0           0
# A00473363TJ8YSZ3YAGG9           0           0           0           0
# A00540051HYJDHVJB2FRO           0           0           0           0
# A0109071NOSV8FSC7VNY            0           0           0           0
#
# ProductId              9759091062  9788071198  ...  B00KWFDBKE  B00L0C529Q  \
# UserId                                         ...
# A0010876CNE3ILIM9HV0            0           0  ...           0           0
# A004205218STRNUW6PPPA           0           0  ...           0           0
# A00473363TJ8YSZ3YAGG9           0           0  ...           0           0
# A00540051HYJDHVJB2FRO           0           0  ...           0           0
# A0109071NOSV8FSC7VNY            0           0  ...           0           0
#
# ProductId              B00L2KVF9W  B00L31Z15E  B00L3K91OW  B00L5JHZJO  \
# UserId
# A0010876CNE3ILIM9HV0            0           0           0           0
# A004205218STRNUW6PPPA           0           0           0           0
# A00473363TJ8YSZ3YAGG9           0           0           0           0
# A00540051HYJDHVJB2FRO           0           0           0           0
# A0109071NOSV8FSC7VNY            0           0           0           0
#
# ProductId              B00L5KTZ0K  B00LBEXC3Q  B00LJEACWC  B00LLPT4HI
# UserId
# A0010876CNE3ILIM9HV0            0           0           0           0
# A004205218STRNUW6PPPA           0           0           0           0
# A00473363TJ8YSZ3YAGG9           0           0           0           0
# A00540051HYJDHVJB2FRO           0           0           0           0
# A0109071NOSV8FSC7VNY            0           0           0           0
#
# [5 rows x 17434 columns]

# %%
ratings_matrix.shape
# Out:
# (24442, 17434)

# %%
X = ratings_matrix.T
X.head()
# Out:
# UserId      A0010876CNE3ILIM9HV0  A004205218STRNUW6PPPA  \
# ProductId
# 1304511081                     0                      0
# 3227001381                     0                      0
# 7535842801                     0                      0
# 832900094X                     0                      0
# 9571044822                     0                      0
#
# UserId      A00473363TJ8YSZ3YAGG9  A00540051HYJDHVJB2FRO  \
# ProductId
# 1304511081                      0                      0
# 3227001381                      0                      0
# 7535842801                      0                      0
# 832900094X                      0                      0
# 9571044822                      0                      0
#
# UserId      A0109071NOSV8FSC7VNY  A0116899HIQEDWSBJJG9  A01198201H0E3GHV2Z17I  \
# ProductId
# 1304511081                     0                     0                      0
# 3227001381                     0                     0                      0
# 7535842801                     0                     0                      0
# 832900094X                     0                     0                      0
# 9571044822                     0                     0                      0
#
# UserId      A0126073315N22OLC73MZ  A01288351ESHZ2KNAXBJ7  \
# ProductId
# 1304511081                      0                      0
# 3227001381                      0                      0
# 7535842801                      0                      0
# 832900094X                      0                      0
# 9571044822                      0                      0
#
# UserId      A0139874ED7NYUB55TSR  ...  AZXC4VH7CHFXR  AZXJ9RA2EQK1E  \
# ProductId                         ...
# 1304511081                     0  ...              0              0
# 3227001381                     0  ...              0              0
# 7535842801                     0  ...              0              0
# 832900094X                     0  ...              0              0
# 9571044822                     0  ...              0              0
#
# UserId      AZYLNZLSXSK9D  AZYM7TVEU0NM  AZYP4WUX6VHRH  AZYPAWSYSCISH  \
# ProductId
# 1304511081              0             0              0              0
# 3227001381              0             0              0              0
# 7535842801              0             0              0              0
# 832900094X              0             0              0              0
# 9571044822              0             0              0              0
#
# UserId      AZYUPMWCE8JBV  AZYZPOORIDNLR  AZZ24BJWAFFES  AZZK6830KW86T
# ProductId
# 1304511081              0              0              0              0
# 3227001381              0              0              0              0
# 7535842801              0              0              0              0
# 832900094X              0              0              0              0
# 9571044822              0              0              0              0
#
# [5 rows x 24442 columns]

# %%
X.shape
# Out:
# (17434, 24442)

# %% [markdown]
# ### Decomposing the Matrix

# %%
SVD = TruncatedSVD(n_components=20)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (17434, 20)

# %% [markdown]
# ### Correlation Matrix

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (17434, 17434)

# %% [markdown]
# B0000AOWL4Assuming the customer buys Product ID # B0000AOWL4 (randomly chosen)

# %%
X.index[250]
# Out:
# 'B0000AOWL4'

# %%
i = "B0000AOWL4"

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 250

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (17434,)

# %% [markdown]
# ### Recommending top 20 highly correlated products in sequence

# %%
Recommended = list(X.index[correlation_product_ID > 0.90])
Recommended.remove(i) 
Recommended[0:20]
# Out:
# ['B00006FE30',
#  'B00017XN7E',
#  'B0002JKQ8K',
#  'B000E3FHJM',
#  'B000GCUU98',
#  'B000OG50Z0',
#  'B000RGYIDM',
#  'B000V5BXO6',
#  'B0017QT5UM',
#  'B001E7688Q',
#  'B001MJT6IA',
#  'B004GL7VE2',
#  'B004OB2C3Y',
#  'B004XJPVAS',
#  'B004Y0V2C2',
#  'B004ZEMHDA',
#  'B0075HPJEI',
#  'B008FIH4IK',
#  'B008JHQ8HU',
#  'B00BCBSJG8']
